# %% [markdown]
# # Date cleaning for SVI
#
# - Accumulate observations with the same date, tau, moneyness
# - Not allow multiple observation for the same moneyness on the same date

# %%
import pandas as pd
import numpy as np
import os


path = "/Users/irtg/Documents/Github/BTC-premia/SVI_independent_tau/"
os.chdir(path)

data_path = os.path.join(path, "Data", "processed","20172022_processed_1_3_4.csv")

# Load the dataset
df = pd.read_csv(data_path)

# Convert 'date' to datetime type for easy grouping
df['date'] = pd.to_datetime(df['date'])

# Data cleaning: Drop rows with IV <= 0 or tau < 3
df = df[(df['IV'] > 0) & (df['tau'] >= 3)]

# Keep rows where 'quantity' is positive
df = df[df['quantity'] > 0]

# Calculate the moneyness: moneyness = K/S - 1
df['moneyness'] = df['K'] / df['BTC_price'] - 1

# Merge rows with the same 'date', 'tau', 'moneyness'
df = df.groupby(['date', 'tau', 'moneyness'], as_index=False).agg({
    'quantity': 'sum',
    'option_price': lambda x: np.average(x, weights=df.loc[x.index, 'quantity']),
    'IV': lambda x: np.average(x, weights=df.loc[x.index, 'quantity'])
    })

# Initialize an empty list to store the ATM IV values for each date
iv_atm_list = []
# Iterate through each unique date and tau to find the ATM IV (where moneyness is closest to 0)
for (date, tau), group in df.groupby(['date', 'tau']):
    closest_row = group.iloc[(group['moneyness']).abs().argsort()[:1]]  # Closest row to moneyness = 0
    iv_atm = closest_row['IV'].values[0]
    moneyness_atm = closest_row['moneyness'].values[0]
    iv_atm_list.append({'date': date, 'tau': tau, 'IV_atm': iv_atm, 'moneyness_atm': moneyness_atm})

# Create a DataFrame from the ATM IV list
iv_atm_df = pd.DataFrame(iv_atm_list)

# Merge the ATM IV values back into the original dataframe
df = df.merge(iv_atm_df, on=['date', 'tau'], how='left')

# Calculate standardized moneyness: standardized_moneyness = (K/S - 1) / IV_atm
# Multiply by 100 for scaling
df['standardized_moneyness'] = df['moneyness']/ df['IV_atm'] * 100

# Save the result to a new CSV file
save_path = os.path.join(path, "data", "processed", "20172022_processed_1_3_5_standardized_moneyness.csv")
df.to_csv(save_path, index=False)

print("Standardized moneyness calculation completed and saved to '20172022_processed_1_3_5_standardized_moneyness.csv'")

# Save the ATM IV values to a new CSV file
save_path = os.path.join(path, "data", "IV", "ATM", "20172022_ATM_IV.csv")
if not os.path.exists(os.path.dirname(save_path)):
    os.makedirs(os.path.dirname(save_path))
iv_atm_df.to_csv(save_path, index=False)

print("ATM IV values saved to '20172022_ATM_IV.csv'")
# Out:
# Standardized moneyness calculation completed and saved to '20172022_processed_1_3_5_standardized_moneyness.csv'
# ATM IV values saved to '20172022_ATM_IV.csv'

# %%
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# Plotting the 3D graph of ATM IV curves
fig = plt.figure(figsize=(12, 8))
ax = fig.add_subplot(111, projection='3d')

# Prepare data for plotting
x = iv_atm_df['date'].map(pd.Timestamp.toordinal) # Convert date to ordinal numbers
y = iv_atm_df['tau']
z = iv_atm_df['IV_atm']

# Plot the surface
ax.scatter(x, y, z, c='b', marker='o')

# Label the axes
ax.set_xlabel('Date')
ax.set_ylabel('Tau')
ax.set_zlabel('ATM IV')
ax.set_title('ATM IV Curves')

# Show the plot
plt.show()

# %%
# Create a new DataFrame with 'date' and 'observations' (number of rows per date)
observations_df = df.groupby('date').size().reset_index(name='observations')

# Save the observations DataFrame to a new CSV file
observations_save_path = os.path.join(path, "data", "processed", "20172022_processed_1_3_5_1_observations.csv")
observations_df.to_csv(observations_save_path, index=False)

print("Observations per date saved to '20172022_processed_1_3_5_1_observations.csv'")
# Out:
# Observations per date saved to '20172022_processed_1_3_5_1_observations.csv'

# %%
print("The size of df is:", df.shape)
# Out:
# The size of df is: (3652201, 9)

# %%
# Create folders for moneyness and standardized moneyness
moneyness_folder = os.path.join(path, "IV", "IV_raw", "unique", "moneyness")
standardized_moneyness_folder = os.path.join(path, "IV", "IV_raw", "unique", "standardized_moneyness")

if not os.path.exists(moneyness_folder):
    os.makedirs(moneyness_folder)

if not os.path.exists(standardized_moneyness_folder):
    os.makedirs(standardized_moneyness_folder)

# Iterate through each unique date to create dataframes for moneyness and standardized moneyness
for date, group in df.groupby('date'):
    # Sort by moneyness and create a DataFrame
    moneyness_df = group.sort_values(by='moneyness')[['moneyness', 'tau', 'IV']]
    moneyness_pivot = moneyness_df.pivot(index='moneyness', columns='tau', values='IV').reset_index()
    moneyness_file_path = os.path.join(moneyness_folder, f"IV_matrix_{date.strftime('%Y-%m-%d')}.csv")
    moneyness_pivot.to_csv(moneyness_file_path, index=False)

    # Sort by standardized moneyness and create a DataFrame
    standardized_moneyness_df = group.sort_values(by='standardized_moneyness')[['standardized_moneyness', 'tau', 'IV']]
    standardized_moneyness_pivot = standardized_moneyness_df.pivot(index='standardized_moneyness', columns='tau', values='IV').reset_index()
    standardized_moneyness_file_path = os.path.join(standardized_moneyness_folder, f"IV_matrix_{date.strftime('%Y-%m-%d')}.csv")
    standardized_moneyness_pivot.to_csv(standardized_moneyness_file_path, index=False)

    print(f"Moneyness and standardized moneyness dataframes saved for date {date.strftime('%Y-%m-%d')}")
# Out:
# Moneyness and standardized moneyness dataframes saved for date 2017-07-01
# Moneyness and standardized moneyness dataframes saved for date 2017-07-02
# Moneyness and standardized moneyness dataframes saved for date 2017-07-03
# Moneyness and standardized moneyness dataframes saved for date 2017-07-04
# Moneyness and standardized moneyness dataframes saved for date 2017-07-05
# Moneyness and standardized moneyness dataframes saved for date 2017-07-06
# Moneyness and standardized moneyness dataframes saved for date 2017-07-07
# Moneyness and standardized moneyness dataframes saved for date 2017-07-08
# Moneyness and standardized moneyness dataframes saved for date 2017-07-09
# Moneyness and standardized moneyness dataframes saved for date 2017-07-10
# Moneyness and standardized moneyness dataframes saved for date 2017-07-11
# Moneyness and standardized moneyness dataframes saved for date 2017-07-12
# Moneyness and standardized moneyness dataframes saved for date 2017-07-13
# Moneyness and standardized moneyness dataframes saved for date 2017-07-14
# Moneyness and standardized moneyness dataframes saved for date 2017-07-15
# Moneyness and standardized moneyness dataframes saved for date 2017-07-16
# Moneyness and standardized moneyness dataframes saved for date 2017-07-17
# Moneyness and standardized moneyness dataframes saved for date 2017-07-18
# Moneyness and standardized moneyness dataframes saved for date 2017-07-19
# Moneyness and standardized moneyness dataframes saved for date 2017-07-20
# Moneyness and standardized moneyness dataframes saved for date 2017-07-21
# Moneyness and standardized moneyness dataframes saved for date 2017-07-22
# Moneyness and standardized moneyness dataframes saved for date 2017-07-23
# Moneyness and standardized moneyness dataframes saved for date 2017-07-24
# Moneyness and standardized moneyness dataframes saved for date 2017-07-25
# Moneyness and standardized moneyness dataframes saved for date 2017-07-26
# Moneyness and standardized moneyness dataframes saved for date 2017-07-27
# Moneyness and standardized moneyness dataframes saved for date 2017-07-28
# Moneyness and standardized moneyness dataframes saved for date 2017-07-29
# Moneyness and standardized moneyness dataframes saved for date 2017-07-30
# Moneyness and standardized moneyness dataframes saved for date 2017-07-31
# Moneyness and standardized moneyness dataframes saved for date 2017-08-01
# Moneyness and standardized moneyness dataframes saved for date 2017-08-02
# Moneyness and standardized moneyness dataframes saved for date 2017-08-03
# Moneyness and standardized moneyness dataframes saved for date 2017-08-04
# Moneyness and standardized moneyness dataframes saved for date 2017-08-05
# Moneyness and standardized moneyness dataframes saved for date 2017-08-06
# Moneyness and standardized moneyness dataframes saved for date 2017-08-07
# Moneyness and standardized moneyness dataframes saved for date 2017-08-08
# Moneyness and standardized moneyness dataframes saved for date 2017-08-09
# Moneyness and standardized moneyness dataframes saved for date 2017-08-10
# Moneyness and standardized moneyness dataframes saved for date 2017-08-11
# Moneyness and standardized moneyness dataframes saved for date 2017-08-12
# Moneyness and standardized moneyness dataframes saved for date 2017-08-13
# Moneyness and standardized moneyness dataframes saved for date 2017-08-14
# Moneyness and standardized moneyness dataframes saved for date 2017-08-15
# Moneyness and standardized moneyness dataframes saved for date 2017-08-16
# Moneyness and standardized moneyness dataframes saved for date 2017-08-17
# Moneyness and standardized moneyness dataframes saved for date 2017-08-18
# Moneyness and standardized moneyness dataframes saved for date 2017-08-19
# Moneyness and standardized moneyness dataframes saved for date 2017-08-20
# Moneyness and standardized moneyness dataframes saved for date 2017-08-21
# Moneyness and standardized moneyness dataframes saved for date 2017-08-22
# Moneyness and standardized moneyness dataframes saved for date 2017-08-23
# Moneyness and standardized moneyness dataframes saved for date 2017-08-24
# Moneyness and standardized moneyness dataframes saved for date 2017-08-25
# Moneyness and standardized moneyness dataframes saved for date 2017-08-26
# Moneyness and standardized moneyness dataframes saved for date 2017-08-27
# Moneyness and standardized moneyness dataframes saved for date 2017-08-28
# Moneyness and standardized moneyness dataframes saved for date 2017-08-29
# Moneyness and standardized moneyness dataframes saved for date 2017-08-30
# Moneyness and standardized moneyness dataframes saved for date 2017-08-31
# Moneyness and standardized moneyness dataframes saved for date 2017-09-01
# Moneyness and standardized moneyness dataframes saved for date 2017-09-02
# Moneyness and standardized moneyness dataframes saved for date 2017-09-03
# Moneyness and standardized moneyness dataframes saved for date 2017-09-04
# Moneyness and standardized moneyness dataframes saved for date 2017-09-05
# Moneyness and standardized moneyness dataframes saved for date 2017-09-06
# Moneyness and standardized moneyness dataframes saved for date 2017-09-07
# Moneyness and standardized moneyness dataframes saved for date 2017-09-08
# Moneyness and standardized moneyness dataframes saved for date 2017-09-09
# Moneyness and standardized moneyness dataframes saved for date 2017-09-10
# Moneyness and standardized moneyness dataframes saved for date 2017-09-11
# Moneyness and standardized moneyness dataframes saved for date 2017-09-12
# Moneyness and standardized moneyness dataframes saved for date 2017-09-13
# Moneyness and standardized moneyness dataframes saved for date 2017-09-14
# Moneyness and standardized moneyness dataframes saved for date 2017-09-15
# Moneyness and standardized moneyness dataframes saved for date 2017-09-16
# Moneyness and standardized moneyness dataframes saved for date 2017-09-17
# Moneyness and standardized moneyness dataframes saved for date 2017-09-18
# Moneyness and standardized moneyness dataframes saved for date 2017-09-19
# Moneyness and standardized moneyness dataframes saved for date 2017-09-20
# Moneyness and standardized moneyness dataframes saved for date 2017-09-21
# Moneyness and standardized moneyness dataframes saved for date 2017-09-22
# Moneyness and standardized moneyness dataframes saved for date 2017-09-23
# Moneyness and standardized moneyness dataframes saved for date 2017-09-24
# Moneyness and standardized moneyness dataframes saved for date 2017-09-25
# Moneyness and standardized moneyness dataframes saved for date 2017-09-26
# Moneyness and standardized moneyness dataframes saved for date 2017-09-27
# Moneyness and standardized moneyness dataframes saved for date 2017-09-28
# Moneyness and standardized moneyness dataframes saved for date 2017-09-29
# Moneyness and standardized moneyness dataframes saved for date 2017-09-30
# Moneyness and standardized moneyness dataframes saved for date 2017-10-01
# Moneyness and standardized moneyness dataframes saved for date 2017-10-02
# Moneyness and standardized moneyness dataframes saved for date 2017-10-03
# Moneyness and standardized moneyness dataframes saved for date 2017-10-04
# Moneyness and standardized moneyness dataframes saved for date 2017-10-05
# Moneyness and standardized moneyness dataframes saved for date 2017-10-06
# Moneyness and standardized moneyness dataframes saved for date 2017-10-07
# Moneyness and standardized moneyness dataframes saved for date 2017-10-08
# Moneyness and standardized moneyness dataframes saved for date 2017-10-09
# Moneyness and standardized moneyness dataframes saved for date 2017-10-10
# Moneyness and standardized moneyness dataframes saved for date 2017-10-11
# Moneyness and standardized moneyness dataframes saved for date 2017-10-12
# Moneyness and standardized moneyness dataframes saved for date 2017-10-13
# Moneyness and standardized moneyness dataframes saved for date 2017-10-14
# Moneyness and standardized moneyness dataframes saved for date 2017-10-15
# Moneyness and standardized moneyness dataframes saved for date 2017-10-16
# Moneyness and standardized moneyness dataframes saved for date 2017-10-17
# Moneyness and standardized moneyness dataframes saved for date 2017-10-18
# Moneyness and standardized moneyness dataframes saved for date 2017-10-19
# Moneyness and standardized moneyness dataframes saved for date 2017-10-20
# Moneyness and standardized moneyness dataframes saved for date 2017-10-21
# Moneyness and standardized moneyness dataframes saved for date 2017-10-22
# Moneyness and standardized moneyness dataframes saved for date 2017-10-23
# Moneyness and standardized moneyness dataframes saved for date 2017-10-24
# Moneyness and standardized moneyness dataframes saved for date 2017-10-25
# Moneyness and standardized moneyness dataframes saved for date 2017-10-26
# Moneyness and standardized moneyness dataframes saved for date 2017-10-27
# Moneyness and standardized moneyness dataframes saved for date 2017-10-28
# Moneyness and standardized moneyness dataframes saved for date 2017-10-29
# Moneyness and standardized moneyness dataframes saved for date 2017-10-30
# Moneyness and standardized moneyness dataframes saved for date 2017-10-31
# Moneyness and standardized moneyness dataframes saved for date 2017-11-01
# Moneyness and standardized moneyness dataframes saved for date 2017-11-02
# Moneyness and standardized moneyness dataframes saved for date 2017-11-03
# Moneyness and standardized moneyness dataframes saved for date 2017-11-04
# Moneyness and standardized moneyness dataframes saved for date 2017-11-05
# Moneyness and standardized moneyness dataframes saved for date 2017-11-06
# Moneyness and standardized moneyness dataframes saved for date 2017-11-07
# Moneyness and standardized moneyness dataframes saved for date 2017-11-08
# Moneyness and standardized moneyness dataframes saved for date 2017-11-09
# Moneyness and standardized moneyness dataframes saved for date 2017-11-10
# Moneyness and standardized moneyness dataframes saved for date 2017-11-11
# Moneyness and standardized moneyness dataframes saved for date 2017-11-12
# Moneyness and standardized moneyness dataframes saved for date 2017-11-13
# Moneyness and standardized moneyness dataframes saved for date 2017-11-14
# Moneyness and standardized moneyness dataframes saved for date 2017-11-15
# Moneyness and standardized moneyness dataframes saved for date 2017-11-16
# Moneyness and standardized moneyness dataframes saved for date 2017-11-17
# Moneyness and standardized moneyness dataframes saved for date 2017-11-18
# Moneyness and standardized moneyness dataframes saved for date 2017-11-19
# Moneyness and standardized moneyness dataframes saved for date 2017-11-20
# Moneyness and standardized moneyness dataframes saved for date 2017-11-21
# Moneyness and standardized moneyness dataframes saved for date 2017-11-22
# Moneyness and standardized moneyness dataframes saved for date 2017-11-23
# Moneyness and standardized moneyness dataframes saved for date 2017-11-24
# Moneyness and standardized moneyness dataframes saved for date 2017-11-25
# Moneyness and standardized moneyness dataframes saved for date 2017-11-26
# Moneyness and standardized moneyness dataframes saved for date 2017-11-27
# Moneyness and standardized moneyness dataframes saved for date 2017-11-28
# Moneyness and standardized moneyness dataframes saved for date 2017-11-29
# Moneyness and standardized moneyness dataframes saved for date 2017-11-30
# Moneyness and standardized moneyness dataframes saved for date 2017-12-01
# Moneyness and standardized moneyness dataframes saved for date 2017-12-02
# Moneyness and standardized moneyness dataframes saved for date 2017-12-03
# Moneyness and standardized moneyness dataframes saved for date 2017-12-04
# Moneyness and standardized moneyness dataframes saved for date 2017-12-05
# Moneyness and standardized moneyness dataframes saved for date 2017-12-06
# Moneyness and standardized moneyness dataframes saved for date 2017-12-07
# Moneyness and standardized moneyness dataframes saved for date 2017-12-08
# Moneyness and standardized moneyness dataframes saved for date 2017-12-09
# Moneyness and standardized moneyness dataframes saved for date 2017-12-10
# Moneyness and standardized moneyness dataframes saved for date 2017-12-11
# Moneyness and standardized moneyness dataframes saved for date 2017-12-12
# Moneyness and standardized moneyness dataframes saved for date 2017-12-13
# Moneyness and standardized moneyness dataframes saved for date 2017-12-14
# Moneyness and standardized moneyness dataframes saved for date 2017-12-15
# Moneyness and standardized moneyness dataframes saved for date 2017-12-16
# Moneyness and standardized moneyness dataframes saved for date 2017-12-17
# Moneyness and standardized moneyness dataframes saved for date 2017-12-18
# Moneyness and standardized moneyness dataframes saved for date 2017-12-19
# Moneyness and standardized moneyness dataframes saved for date 2017-12-20
# Moneyness and standardized moneyness dataframes saved for date 2017-12-21
# Moneyness and standardized moneyness dataframes saved for date 2017-12-22
# Moneyness and standardized moneyness dataframes saved for date 2017-12-23
# Moneyness and standardized moneyness dataframes saved for date 2017-12-24
# Moneyness and standardized moneyness dataframes saved for date 2017-12-25
# Moneyness and standardized moneyness dataframes saved for date 2017-12-26
# Moneyness and standardized moneyness dataframes saved for date 2017-12-27
# Moneyness and standardized moneyness dataframes saved for date 2017-12-28
# Moneyness and standardized moneyness dataframes saved for date 2017-12-29
# Moneyness and standardized moneyness dataframes saved for date 2017-12-30
# Moneyness and standardized moneyness dataframes saved for date 2017-12-31
# Moneyness and standardized moneyness dataframes saved for date 2018-01-01
# Moneyness and standardized moneyness dataframes saved for date 2018-01-02
# Moneyness and standardized moneyness dataframes saved for date 2018-01-03
# Moneyness and standardized moneyness dataframes saved for date 2018-01-04
# Moneyness and standardized moneyness dataframes saved for date 2018-01-05
# Moneyness and standardized moneyness dataframes saved for date 2018-01-06
# Moneyness and standardized moneyness dataframes saved for date 2018-01-07
# Moneyness and standardized moneyness dataframes saved for date 2018-01-08
# Moneyness and standardized moneyness dataframes saved for date 2018-01-09
# Moneyness and standardized moneyness dataframes saved for date 2018-01-10
# Moneyness and standardized moneyness dataframes saved for date 2018-01-11
# Moneyness and standardized moneyness dataframes saved for date 2018-01-12
# Moneyness and standardized moneyness dataframes saved for date 2018-01-13
# Moneyness and standardized moneyness dataframes saved for date 2018-01-14
# Moneyness and standardized moneyness dataframes saved for date 2018-01-15
# Moneyness and standardized moneyness dataframes saved for date 2018-01-16
# Moneyness and standardized moneyness dataframes saved for date 2018-01-17
# Moneyness and standardized moneyness dataframes saved for date 2018-01-18
# Moneyness and standardized moneyness dataframes saved for date 2018-01-19
# Moneyness and standardized moneyness dataframes saved for date 2018-01-20
# Moneyness and standardized moneyness dataframes saved for date 2018-01-21
# Moneyness and standardized moneyness dataframes saved for date 2018-01-22
# Moneyness and standardized moneyness dataframes saved for date 2018-01-23
# Moneyness and standardized moneyness dataframes saved for date 2018-01-24
# Moneyness and standardized moneyness dataframes saved for date 2018-01-25
# Moneyness and standardized moneyness dataframes saved for date 2018-01-26
# Moneyness and standardized moneyness dataframes saved for date 2018-01-27
# Moneyness and standardized moneyness dataframes saved for date 2018-01-28
# Moneyness and standardized moneyness dataframes saved for date 2018-01-29
# Moneyness and standardized moneyness dataframes saved for date 2018-01-30
# Moneyness and standardized moneyness dataframes saved for date 2018-01-31
# Moneyness and standardized moneyness dataframes saved for date 2018-02-01
# Moneyness and standardized moneyness dataframes saved for date 2018-02-02
# Moneyness and standardized moneyness dataframes saved for date 2018-02-03
# Moneyness and standardized moneyness dataframes saved for date 2018-02-04
# Moneyness and standardized moneyness dataframes saved for date 2018-02-05
# Moneyness and standardized moneyness dataframes saved for date 2018-02-06
# Moneyness and standardized moneyness dataframes saved for date 2018-02-07
# Moneyness and standardized moneyness dataframes saved for date 2018-02-08
# Moneyness and standardized moneyness dataframes saved for date 2018-02-09
# Moneyness and standardized moneyness dataframes saved for date 2018-02-10
# Moneyness and standardized moneyness dataframes saved for date 2018-02-11
# Moneyness and standardized moneyness dataframes saved for date 2018-02-12
# Moneyness and standardized moneyness dataframes saved for date 2018-02-13
# Moneyness and standardized moneyness dataframes saved for date 2018-02-14
# Moneyness and standardized moneyness dataframes saved for date 2018-02-15
# Moneyness and standardized moneyness dataframes saved for date 2018-02-16
# Moneyness and standardized moneyness dataframes saved for date 2018-02-17
# Moneyness and standardized moneyness dataframes saved for date 2018-02-18
# Moneyness and standardized moneyness dataframes saved for date 2018-02-19
# Moneyness and standardized moneyness dataframes saved for date 2018-02-20
# Moneyness and standardized moneyness dataframes saved for date 2018-02-21
# Moneyness and standardized moneyness dataframes saved for date 2018-02-22
# Moneyness and standardized moneyness dataframes saved for date 2018-02-23
# Moneyness and standardized moneyness dataframes saved for date 2018-02-24
# Moneyness and standardized moneyness dataframes saved for date 2018-02-25
# Moneyness and standardized moneyness dataframes saved for date 2018-02-26
# Moneyness and standardized moneyness dataframes saved for date 2018-02-27
# Moneyness and standardized moneyness dataframes saved for date 2018-02-28
# Moneyness and standardized moneyness dataframes saved for date 2018-03-01
# Moneyness and standardized moneyness dataframes saved for date 2018-03-02
# Moneyness and standardized moneyness dataframes saved for date 2018-03-03
# Moneyness and standardized moneyness dataframes saved for date 2018-03-04
# Moneyness and standardized moneyness dataframes saved for date 2018-03-05
# Moneyness and standardized moneyness dataframes saved for date 2018-03-06
# Moneyness and standardized moneyness dataframes saved for date 2018-03-07
# Moneyness and standardized moneyness dataframes saved for date 2018-03-08
# Moneyness and standardized moneyness dataframes saved for date 2018-03-09
# Moneyness and standardized moneyness dataframes saved for date 2018-03-10
# Moneyness and standardized moneyness dataframes saved for date 2018-03-11
# Moneyness and standardized moneyness dataframes saved for date 2018-03-12
# Moneyness and standardized moneyness dataframes saved for date 2018-03-13
# Moneyness and standardized moneyness dataframes saved for date 2018-03-14
# Moneyness and standardized moneyness dataframes saved for date 2018-03-15
# Moneyness and standardized moneyness dataframes saved for date 2018-03-16
# Moneyness and standardized moneyness dataframes saved for date 2018-03-17
# Moneyness and standardized moneyness dataframes saved for date 2018-03-18
# Moneyness and standardized moneyness dataframes saved for date 2018-03-19
# Moneyness and standardized moneyness dataframes saved for date 2018-03-20
# Moneyness and standardized moneyness dataframes saved for date 2018-03-21
# Moneyness and standardized moneyness dataframes saved for date 2018-03-22
# Moneyness and standardized moneyness dataframes saved for date 2018-03-23
# Moneyness and standardized moneyness dataframes saved for date 2018-03-24
# Moneyness and standardized moneyness dataframes saved for date 2018-03-25
# Moneyness and standardized moneyness dataframes saved for date 2018-03-26
# Moneyness and standardized moneyness dataframes saved for date 2018-03-27
# Moneyness and standardized moneyness dataframes saved for date 2018-03-28
# Moneyness and standardized moneyness dataframes saved for date 2018-03-29
# Moneyness and standardized moneyness dataframes saved for date 2018-03-30
# Moneyness and standardized moneyness dataframes saved for date 2018-03-31
# Moneyness and standardized moneyness dataframes saved for date 2018-04-01
# Moneyness and standardized moneyness dataframes saved for date 2018-04-02
# Moneyness and standardized moneyness dataframes saved for date 2018-04-03
# Moneyness and standardized moneyness dataframes saved for date 2018-04-04
# Moneyness and standardized moneyness dataframes saved for date 2018-04-05
# Moneyness and standardized moneyness dataframes saved for date 2018-04-06
# Moneyness and standardized moneyness dataframes saved for date 2018-04-07
# Moneyness and standardized moneyness dataframes saved for date 2018-04-08
# Moneyness and standardized moneyness dataframes saved for date 2018-04-09
# Moneyness and standardized moneyness dataframes saved for date 2018-04-10
# Moneyness and standardized moneyness dataframes saved for date 2018-04-11
# Moneyness and standardized moneyness dataframes saved for date 2018-04-12
# Moneyness and standardized moneyness dataframes saved for date 2018-04-13
# Moneyness and standardized moneyness dataframes saved for date 2018-04-14
# Moneyness and standardized moneyness dataframes saved for date 2018-04-15
# Moneyness and standardized moneyness dataframes saved for date 2018-04-16
# Moneyness and standardized moneyness dataframes saved for date 2018-04-17
# Moneyness and standardized moneyness dataframes saved for date 2018-04-18
# Moneyness and standardized moneyness dataframes saved for date 2018-04-19
# Moneyness and standardized moneyness dataframes saved for date 2018-04-20
# Moneyness and standardized moneyness dataframes saved for date 2018-04-21
# Moneyness and standardized moneyness dataframes saved for date 2018-04-22
# Moneyness and standardized moneyness dataframes saved for date 2018-04-23
# Moneyness and standardized moneyness dataframes saved for date 2018-04-24
# Moneyness and standardized moneyness dataframes saved for date 2018-04-25
# Moneyness and standardized moneyness dataframes saved for date 2018-04-26
# Moneyness and standardized moneyness dataframes saved for date 2018-04-27
# Moneyness and standardized moneyness dataframes saved for date 2018-04-28
# Moneyness and standardized moneyness dataframes saved for date 2018-04-29
# Moneyness and standardized moneyness dataframes saved for date 2018-04-30
# Moneyness and standardized moneyness dataframes saved for date 2018-05-01
# Moneyness and standardized moneyness dataframes saved for date 2018-05-02
# Moneyness and standardized moneyness dataframes saved for date 2018-05-03
# Moneyness and standardized moneyness dataframes saved for date 2018-05-04
# Moneyness and standardized moneyness dataframes saved for date 2018-05-05
# Moneyness and standardized moneyness dataframes saved for date 2018-05-06
# Moneyness and standardized moneyness dataframes saved for date 2018-05-07
# Moneyness and standardized moneyness dataframes saved for date 2018-05-08
# Moneyness and standardized moneyness dataframes saved for date 2018-05-09
# Moneyness and standardized moneyness dataframes saved for date 2018-05-10
# Moneyness and standardized moneyness dataframes saved for date 2018-05-11
# Moneyness and standardized moneyness dataframes saved for date 2018-05-12
# Moneyness and standardized moneyness dataframes saved for date 2018-05-13
# Moneyness and standardized moneyness dataframes saved for date 2018-05-14
# Moneyness and standardized moneyness dataframes saved for date 2018-05-15
# Moneyness and standardized moneyness dataframes saved for date 2018-05-16
# Moneyness and standardized moneyness dataframes saved for date 2018-05-17
# Moneyness and standardized moneyness dataframes saved for date 2018-05-18
# Moneyness and standardized moneyness dataframes saved for date 2018-05-19
# Moneyness and standardized moneyness dataframes saved for date 2018-05-20
# Moneyness and standardized moneyness dataframes saved for date 2018-05-21
# Moneyness and standardized moneyness dataframes saved for date 2018-05-22
# Moneyness and standardized moneyness dataframes saved for date 2018-05-23
# Moneyness and standardized moneyness dataframes saved for date 2018-05-24
# Moneyness and standardized moneyness dataframes saved for date 2018-05-25
# Moneyness and standardized moneyness dataframes saved for date 2018-05-26
# Moneyness and standardized moneyness dataframes saved for date 2018-05-27
# Moneyness and standardized moneyness dataframes saved for date 2018-05-28
# Moneyness and standardized moneyness dataframes saved for date 2018-05-29
# Moneyness and standardized moneyness dataframes saved for date 2018-05-30
# Moneyness and standardized moneyness dataframes saved for date 2018-05-31
# Moneyness and standardized moneyness dataframes saved for date 2018-06-01
# Moneyness and standardized moneyness dataframes saved for date 2018-06-02
# Moneyness and standardized moneyness dataframes saved for date 2018-06-03
# Moneyness and standardized moneyness dataframes saved for date 2018-06-04
# Moneyness and standardized moneyness dataframes saved for date 2018-06-05
# Moneyness and standardized moneyness dataframes saved for date 2018-06-06
# Moneyness and standardized moneyness dataframes saved for date 2018-06-07
# Moneyness and standardized moneyness dataframes saved for date 2018-06-08
# Moneyness and standardized moneyness dataframes saved for date 2018-06-09
# Moneyness and standardized moneyness dataframes saved for date 2018-06-10
# Moneyness and standardized moneyness dataframes saved for date 2018-06-11
# Moneyness and standardized moneyness dataframes saved for date 2018-06-12
# Moneyness and standardized moneyness dataframes saved for date 2018-06-13
# Moneyness and standardized moneyness dataframes saved for date 2018-06-14
# Moneyness and standardized moneyness dataframes saved for date 2018-06-15
# Moneyness and standardized moneyness dataframes saved for date 2018-06-16
# Moneyness and standardized moneyness dataframes saved for date 2018-06-17
# Moneyness and standardized moneyness dataframes saved for date 2018-06-18
# Moneyness and standardized moneyness dataframes saved for date 2018-06-19
# Moneyness and standardized moneyness dataframes saved for date 2018-06-20
# Moneyness and standardized moneyness dataframes saved for date 2018-06-21
# Moneyness and standardized moneyness dataframes saved for date 2018-06-22
# Moneyness and standardized moneyness dataframes saved for date 2018-06-23
# Moneyness and standardized moneyness dataframes saved for date 2018-06-24
# Moneyness and standardized moneyness dataframes saved for date 2018-06-25
# Moneyness and standardized moneyness dataframes saved for date 2018-06-26
# Moneyness and standardized moneyness dataframes saved for date 2018-06-27
# Moneyness and standardized moneyness dataframes saved for date 2018-06-28
# Moneyness and standardized moneyness dataframes saved for date 2018-06-29
# Moneyness and standardized moneyness dataframes saved for date 2018-06-30
# Moneyness and standardized moneyness dataframes saved for date 2018-07-01
# Moneyness and standardized moneyness dataframes saved for date 2018-07-02
# Moneyness and standardized moneyness dataframes saved for date 2018-07-03
# Moneyness and standardized moneyness dataframes saved for date 2018-07-04
# Moneyness and standardized moneyness dataframes saved for date 2018-07-05
# Moneyness and standardized moneyness dataframes saved for date 2018-07-06
# Moneyness and standardized moneyness dataframes saved for date 2018-07-07
# Moneyness and standardized moneyness dataframes saved for date 2018-07-08
# Moneyness and standardized moneyness dataframes saved for date 2018-07-09
# Moneyness and standardized moneyness dataframes saved for date 2018-07-10
# Moneyness and standardized moneyness dataframes saved for date 2018-07-11
# Moneyness and standardized moneyness dataframes saved for date 2018-07-12
# Moneyness and standardized moneyness dataframes saved for date 2018-07-13
# Moneyness and standardized moneyness dataframes saved for date 2018-07-14
# Moneyness and standardized moneyness dataframes saved for date 2018-07-15
# Moneyness and standardized moneyness dataframes saved for date 2018-07-16
# Moneyness and standardized moneyness dataframes saved for date 2018-07-17
# Moneyness and standardized moneyness dataframes saved for date 2018-07-18
# Moneyness and standardized moneyness dataframes saved for date 2018-07-19
# Moneyness and standardized moneyness dataframes saved for date 2018-07-20
# Moneyness and standardized moneyness dataframes saved for date 2018-07-21
# Moneyness and standardized moneyness dataframes saved for date 2018-07-22
# Moneyness and standardized moneyness dataframes saved for date 2018-07-23
# Moneyness and standardized moneyness dataframes saved for date 2018-07-24
# Moneyness and standardized moneyness dataframes saved for date 2018-07-25
# Moneyness and standardized moneyness dataframes saved for date 2018-07-26
# Moneyness and standardized moneyness dataframes saved for date 2018-07-27
# Moneyness and standardized moneyness dataframes saved for date 2018-07-28
# Moneyness and standardized moneyness dataframes saved for date 2018-07-29
# Moneyness and standardized moneyness dataframes saved for date 2018-07-30
# Moneyness and standardized moneyness dataframes saved for date 2018-07-31
# Moneyness and standardized moneyness dataframes saved for date 2018-08-01
# Moneyness and standardized moneyness dataframes saved for date 2018-08-02
# Moneyness and standardized moneyness dataframes saved for date 2018-08-03
# Moneyness and standardized moneyness dataframes saved for date 2018-08-04
# Moneyness and standardized moneyness dataframes saved for date 2018-08-05
# Moneyness and standardized moneyness dataframes saved for date 2018-08-06
# Moneyness and standardized moneyness dataframes saved for date 2018-08-07
# Moneyness and standardized moneyness dataframes saved for date 2018-08-08
# Moneyness and standardized moneyness dataframes saved for date 2018-08-09
# Moneyness and standardized moneyness dataframes saved for date 2018-08-10
# Moneyness and standardized moneyness dataframes saved for date 2018-08-11
# Moneyness and standardized moneyness dataframes saved for date 2018-08-12
# Moneyness and standardized moneyness dataframes saved for date 2018-08-13
# Moneyness and standardized moneyness dataframes saved for date 2018-08-14
# Moneyness and standardized moneyness dataframes saved for date 2018-08-15
# Moneyness and standardized moneyness dataframes saved for date 2018-08-16
# Moneyness and standardized moneyness dataframes saved for date 2018-08-17
# Moneyness and standardized moneyness dataframes saved for date 2018-08-18
# Moneyness and standardized moneyness dataframes saved for date 2018-08-19
# Moneyness and standardized moneyness dataframes saved for date 2018-08-20
# Moneyness and standardized moneyness dataframes saved for date 2018-08-21
# Moneyness and standardized moneyness dataframes saved for date 2018-08-22
# Moneyness and standardized moneyness dataframes saved for date 2018-08-23
# Moneyness and standardized moneyness dataframes saved for date 2018-08-24
# Moneyness and standardized moneyness dataframes saved for date 2018-08-25
# Moneyness and standardized moneyness dataframes saved for date 2018-08-26
# Moneyness and standardized moneyness dataframes saved for date 2018-08-27
# Moneyness and standardized moneyness dataframes saved for date 2018-08-28
# Moneyness and standardized moneyness dataframes saved for date 2018-08-29
# Moneyness and standardized moneyness dataframes saved for date 2018-08-30
# Moneyness and standardized moneyness dataframes saved for date 2018-08-31
# Moneyness and standardized moneyness dataframes saved for date 2018-09-01
# Moneyness and standardized moneyness dataframes saved for date 2018-09-02
# Moneyness and standardized moneyness dataframes saved for date 2018-09-03
# Moneyness and standardized moneyness dataframes saved for date 2018-09-04
# Moneyness and standardized moneyness dataframes saved for date 2018-09-05
# Moneyness and standardized moneyness dataframes saved for date 2018-09-06
# Moneyness and standardized moneyness dataframes saved for date 2018-09-07
# Moneyness and standardized moneyness dataframes saved for date 2018-09-08
# Moneyness and standardized moneyness dataframes saved for date 2018-09-09
# Moneyness and standardized moneyness dataframes saved for date 2018-09-10
# Moneyness and standardized moneyness dataframes saved for date 2018-09-11
# Moneyness and standardized moneyness dataframes saved for date 2018-09-12
# Moneyness and standardized moneyness dataframes saved for date 2018-09-13
# Moneyness and standardized moneyness dataframes saved for date 2018-09-14
# Moneyness and standardized moneyness dataframes saved for date 2018-09-15
# Moneyness and standardized moneyness dataframes saved for date 2018-09-16
# Moneyness and standardized moneyness dataframes saved for date 2018-09-17
# Moneyness and standardized moneyness dataframes saved for date 2018-09-18
# Moneyness and standardized moneyness dataframes saved for date 2018-09-19
# Moneyness and standardized moneyness dataframes saved for date 2018-09-20
# Moneyness and standardized moneyness dataframes saved for date 2018-09-21
# Moneyness and standardized moneyness dataframes saved for date 2018-09-22
# Moneyness and standardized moneyness dataframes saved for date 2018-09-23
# Moneyness and standardized moneyness dataframes saved for date 2018-09-24
# Moneyness and standardized moneyness dataframes saved for date 2018-09-25
# Moneyness and standardized moneyness dataframes saved for date 2018-09-26
# Moneyness and standardized moneyness dataframes saved for date 2018-09-27
# Moneyness and standardized moneyness dataframes saved for date 2018-09-28
# Moneyness and standardized moneyness dataframes saved for date 2018-09-29
# Moneyness and standardized moneyness dataframes saved for date 2018-09-30
# Moneyness and standardized moneyness dataframes saved for date 2018-10-01
# Moneyness and standardized moneyness dataframes saved for date 2018-10-02
# Moneyness and standardized moneyness dataframes saved for date 2018-10-03
# Moneyness and standardized moneyness dataframes saved for date 2018-10-04
# Moneyness and standardized moneyness dataframes saved for date 2018-10-05
# Moneyness and standardized moneyness dataframes saved for date 2018-10-06
# Moneyness and standardized moneyness dataframes saved for date 2018-10-07
# Moneyness and standardized moneyness dataframes saved for date 2018-10-08
# Moneyness and standardized moneyness dataframes saved for date 2018-10-09
# Moneyness and standardized moneyness dataframes saved for date 2018-10-10
# Moneyness and standardized moneyness dataframes saved for date 2018-10-11
# Moneyness and standardized moneyness dataframes saved for date 2018-10-12
# Moneyness and standardized moneyness dataframes saved for date 2018-10-13
# Moneyness and standardized moneyness dataframes saved for date 2018-10-14
# Moneyness and standardized moneyness dataframes saved for date 2018-10-15
# Moneyness and standardized moneyness dataframes saved for date 2018-10-16
# Moneyness and standardized moneyness dataframes saved for date 2018-10-17
# Moneyness and standardized moneyness dataframes saved for date 2018-10-18
# Moneyness and standardized moneyness dataframes saved for date 2018-10-19
# Moneyness and standardized moneyness dataframes saved for date 2018-10-20
# Moneyness and standardized moneyness dataframes saved for date 2018-10-21
# Moneyness and standardized moneyness dataframes saved for date 2018-10-22
# Moneyness and standardized moneyness dataframes saved for date 2018-10-23
# Moneyness and standardized moneyness dataframes saved for date 2018-10-24
# Moneyness and standardized moneyness dataframes saved for date 2018-10-25
# Moneyness and standardized moneyness dataframes saved for date 2018-10-26
# Moneyness and standardized moneyness dataframes saved for date 2018-10-27
# Moneyness and standardized moneyness dataframes saved for date 2018-10-28
# Moneyness and standardized moneyness dataframes saved for date 2018-10-29
# Moneyness and standardized moneyness dataframes saved for date 2018-10-30
# Moneyness and standardized moneyness dataframes saved for date 2018-10-31
# Moneyness and standardized moneyness dataframes saved for date 2018-11-01
# Moneyness and standardized moneyness dataframes saved for date 2018-11-02
# Moneyness and standardized moneyness dataframes saved for date 2018-11-03
# Moneyness and standardized moneyness dataframes saved for date 2018-11-04
# Moneyness and standardized moneyness dataframes saved for date 2018-11-05
# Moneyness and standardized moneyness dataframes saved for date 2018-11-06
# Moneyness and standardized moneyness dataframes saved for date 2018-11-07
# Moneyness and standardized moneyness dataframes saved for date 2018-11-08
# Moneyness and standardized moneyness dataframes saved for date 2018-11-09
# Moneyness and standardized moneyness dataframes saved for date 2018-11-10
# Moneyness and standardized moneyness dataframes saved for date 2018-11-11
# Moneyness and standardized moneyness dataframes saved for date 2018-11-12
# Moneyness and standardized moneyness dataframes saved for date 2018-11-13
# Moneyness and standardized moneyness dataframes saved for date 2018-11-14
# Moneyness and standardized moneyness dataframes saved for date 2018-11-15
# Moneyness and standardized moneyness dataframes saved for date 2018-11-16
# Moneyness and standardized moneyness dataframes saved for date 2018-11-17
# Moneyness and standardized moneyness dataframes saved for date 2018-11-18
# Moneyness and standardized moneyness dataframes saved for date 2018-11-19
# Moneyness and standardized moneyness dataframes saved for date 2018-11-20
# Moneyness and standardized moneyness dataframes saved for date 2018-11-21
# Moneyness and standardized moneyness dataframes saved for date 2018-11-22
# Moneyness and standardized moneyness dataframes saved for date 2018-11-23
# Moneyness and standardized moneyness dataframes saved for date 2018-11-24
# Moneyness and standardized moneyness dataframes saved for date 2018-11-25
# Moneyness and standardized moneyness dataframes saved for date 2018-11-26
# Moneyness and standardized moneyness dataframes saved for date 2018-11-27
# Moneyness and standardized moneyness dataframes saved for date 2018-11-28
# Moneyness and standardized moneyness dataframes saved for date 2018-11-29
# Moneyness and standardized moneyness dataframes saved for date 2018-11-30
# Moneyness and standardized moneyness dataframes saved for date 2018-12-01
# Moneyness and standardized moneyness dataframes saved for date 2018-12-02
# Moneyness and standardized moneyness dataframes saved for date 2018-12-03
# Moneyness and standardized moneyness dataframes saved for date 2018-12-04
# Moneyness and standardized moneyness dataframes saved for date 2018-12-05
# Moneyness and standardized moneyness dataframes saved for date 2018-12-06
# Moneyness and standardized moneyness dataframes saved for date 2018-12-07
# Moneyness and standardized moneyness dataframes saved for date 2018-12-08
# Moneyness and standardized moneyness dataframes saved for date 2018-12-09
# Moneyness and standardized moneyness dataframes saved for date 2018-12-10
# Moneyness and standardized moneyness dataframes saved for date 2018-12-11
# Moneyness and standardized moneyness dataframes saved for date 2018-12-12
# Moneyness and standardized moneyness dataframes saved for date 2018-12-13
# Moneyness and standardized moneyness dataframes saved for date 2018-12-14
# Moneyness and standardized moneyness dataframes saved for date 2018-12-15
# Moneyness and standardized moneyness dataframes saved for date 2018-12-16
# Moneyness and standardized moneyness dataframes saved for date 2018-12-17
# Moneyness and standardized moneyness dataframes saved for date 2018-12-18
# Moneyness and standardized moneyness dataframes saved for date 2018-12-19
# Moneyness and standardized moneyness dataframes saved for date 2018-12-20
# Moneyness and standardized moneyness dataframes saved for date 2018-12-21
# Moneyness and standardized moneyness dataframes saved for date 2018-12-22
# Moneyness and standardized moneyness dataframes saved for date 2018-12-23
# Moneyness and standardized moneyness dataframes saved for date 2018-12-24
# Moneyness and standardized moneyness dataframes saved for date 2018-12-25
# Moneyness and standardized moneyness dataframes saved for date 2018-12-26
# Moneyness and standardized moneyness dataframes saved for date 2018-12-27
# Moneyness and standardized moneyness dataframes saved for date 2018-12-28
# Moneyness and standardized moneyness dataframes saved for date 2018-12-29
# Moneyness and standardized moneyness dataframes saved for date 2018-12-30
# Moneyness and standardized moneyness dataframes saved for date 2018-12-31
# Moneyness and standardized moneyness dataframes saved for date 2019-01-01
# Moneyness and standardized moneyness dataframes saved for date 2019-01-02
# Moneyness and standardized moneyness dataframes saved for date 2019-01-03
# Moneyness and standardized moneyness dataframes saved for date 2019-01-04
# Moneyness and standardized moneyness dataframes saved for date 2019-01-05
# Moneyness and standardized moneyness dataframes saved for date 2019-01-06
# Moneyness and standardized moneyness dataframes saved for date 2019-01-07
# Moneyness and standardized moneyness dataframes saved for date 2019-01-08
# Moneyness and standardized moneyness dataframes saved for date 2019-01-09
# Moneyness and standardized moneyness dataframes saved for date 2019-01-10
# Moneyness and standardized moneyness dataframes saved for date 2019-01-11
# Moneyness and standardized moneyness dataframes saved for date 2019-01-12
# Moneyness and standardized moneyness dataframes saved for date 2019-01-13
# Moneyness and standardized moneyness dataframes saved for date 2019-01-14
# Moneyness and standardized moneyness dataframes saved for date 2019-01-15
# Moneyness and standardized moneyness dataframes saved for date 2019-01-16
# Moneyness and standardized moneyness dataframes saved for date 2019-01-17
# Moneyness and standardized moneyness dataframes saved for date 2019-01-18
# Moneyness and standardized moneyness dataframes saved for date 2019-01-19
# Moneyness and standardized moneyness dataframes saved for date 2019-01-20
# Moneyness and standardized moneyness dataframes saved for date 2019-01-21
# Moneyness and standardized moneyness dataframes saved for date 2019-01-22
# Moneyness and standardized moneyness dataframes saved for date 2019-01-23
# Moneyness and standardized moneyness dataframes saved for date 2019-01-24
# Moneyness and standardized moneyness dataframes saved for date 2019-01-25
# Moneyness and standardized moneyness dataframes saved for date 2019-01-26
# Moneyness and standardized moneyness dataframes saved for date 2019-01-27
# Moneyness and standardized moneyness dataframes saved for date 2019-01-28
# Moneyness and standardized moneyness dataframes saved for date 2019-01-29
# Moneyness and standardized moneyness dataframes saved for date 2019-01-30
# Moneyness and standardized moneyness dataframes saved for date 2019-01-31
# Moneyness and standardized moneyness dataframes saved for date 2019-02-01
# Moneyness and standardized moneyness dataframes saved for date 2019-02-02
# Moneyness and standardized moneyness dataframes saved for date 2019-02-03
# Moneyness and standardized moneyness dataframes saved for date 2019-02-04
# Moneyness and standardized moneyness dataframes saved for date 2019-02-05
# Moneyness and standardized moneyness dataframes saved for date 2019-02-06
# Moneyness and standardized moneyness dataframes saved for date 2019-02-07
# Moneyness and standardized moneyness dataframes saved for date 2019-02-08
# Moneyness and standardized moneyness dataframes saved for date 2019-02-09
# Moneyness and standardized moneyness dataframes saved for date 2019-02-10
# Moneyness and standardized moneyness dataframes saved for date 2019-02-11
# Moneyness and standardized moneyness dataframes saved for date 2019-02-12
# Moneyness and standardized moneyness dataframes saved for date 2019-02-13
# Moneyness and standardized moneyness dataframes saved for date 2019-02-14
# Moneyness and standardized moneyness dataframes saved for date 2019-02-15
# Moneyness and standardized moneyness dataframes saved for date 2019-02-16
# Moneyness and standardized moneyness dataframes saved for date 2019-02-17
# Moneyness and standardized moneyness dataframes saved for date 2019-02-18
# Moneyness and standardized moneyness dataframes saved for date 2019-02-19
# Moneyness and standardized moneyness dataframes saved for date 2019-02-20
# Moneyness and standardized moneyness dataframes saved for date 2019-02-21
# Moneyness and standardized moneyness dataframes saved for date 2019-02-22
# Moneyness and standardized moneyness dataframes saved for date 2019-02-23
# Moneyness and standardized moneyness dataframes saved for date 2019-02-24
# Moneyness and standardized moneyness dataframes saved for date 2019-02-25
# Moneyness and standardized moneyness dataframes saved for date 2019-02-26
# Moneyness and standardized moneyness dataframes saved for date 2019-02-27
# Moneyness and standardized moneyness dataframes saved for date 2019-02-28
# Moneyness and standardized moneyness dataframes saved for date 2019-03-01
# Moneyness and standardized moneyness dataframes saved for date 2019-03-02
# Moneyness and standardized moneyness dataframes saved for date 2019-03-03
# Moneyness and standardized moneyness dataframes saved for date 2019-03-04
# Moneyness and standardized moneyness dataframes saved for date 2019-03-05
# Moneyness and standardized moneyness dataframes saved for date 2019-03-06
# Moneyness and standardized moneyness dataframes saved for date 2019-03-07
# Moneyness and standardized moneyness dataframes saved for date 2019-03-08
# Moneyness and standardized moneyness dataframes saved for date 2019-03-09
# Moneyness and standardized moneyness dataframes saved for date 2019-03-10
# Moneyness and standardized moneyness dataframes saved for date 2019-03-11
# Moneyness and standardized moneyness dataframes saved for date 2019-03-12
# Moneyness and standardized moneyness dataframes saved for date 2019-03-13
# Moneyness and standardized moneyness dataframes saved for date 2019-03-14
# Moneyness and standardized moneyness dataframes saved for date 2019-03-15
# Moneyness and standardized moneyness dataframes saved for date 2019-03-16
# Moneyness and standardized moneyness dataframes saved for date 2019-03-17
# Moneyness and standardized moneyness dataframes saved for date 2019-03-18
# Moneyness and standardized moneyness dataframes saved for date 2019-03-19
# Moneyness and standardized moneyness dataframes saved for date 2019-03-20
# Moneyness and standardized moneyness dataframes saved for date 2019-03-21
# Moneyness and standardized moneyness dataframes saved for date 2019-03-22
# Moneyness and standardized moneyness dataframes saved for date 2019-03-23
# Moneyness and standardized moneyness dataframes saved for date 2019-03-24
# Moneyness and standardized moneyness dataframes saved for date 2019-03-25
# Moneyness and standardized moneyness dataframes saved for date 2019-03-26
# Moneyness and standardized moneyness dataframes saved for date 2019-03-27
# Moneyness and standardized moneyness dataframes saved for date 2019-03-28
# Moneyness and standardized moneyness dataframes saved for date 2019-03-29
# Moneyness and standardized moneyness dataframes saved for date 2019-03-30
# Moneyness and standardized moneyness dataframes saved for date 2019-03-31
# Moneyness and standardized moneyness dataframes saved for date 2019-04-01
# Moneyness and standardized moneyness dataframes saved for date 2019-04-02
# Moneyness and standardized moneyness dataframes saved for date 2019-04-03
# Moneyness and standardized moneyness dataframes saved for date 2019-04-04
# Moneyness and standardized moneyness dataframes saved for date 2019-04-05
# Moneyness and standardized moneyness dataframes saved for date 2019-04-06
# Moneyness and standardized moneyness dataframes saved for date 2019-04-07
# Moneyness and standardized moneyness dataframes saved for date 2019-04-08
# Moneyness and standardized moneyness dataframes saved for date 2019-04-09
# ...
# Moneyness and standardized moneyness dataframes saved for date 2022-05-12
# Moneyness and standardized moneyness dataframes saved for date 2022-05-13
# Moneyness and standardized moneyness dataframes saved for date 2022-05-14
# Moneyness and standardized moneyness dataframes saved for date 2022-05-15
# Moneyness and standardized moneyness dataframes saved for date 2022-05-16
# Moneyness and standardized moneyness dataframes saved for date 2022-05-17
# Moneyness and standardized moneyness dataframes saved for date 2022-05-18
# Moneyness and standardized moneyness dataframes saved for date 2022-05-19
# Moneyness and standardized moneyness dataframes saved for date 2022-05-20
# Moneyness and standardized moneyness dataframes saved for date 2022-05-21
# Moneyness and standardized moneyness dataframes saved for date 2022-05-22
# Moneyness and standardized moneyness dataframes saved for date 2022-05-23
# Moneyness and standardized moneyness dataframes saved for date 2022-05-24
# Moneyness and standardized moneyness dataframes saved for date 2022-05-25
# Moneyness and standardized moneyness dataframes saved for date 2022-05-26
# Moneyness and standardized moneyness dataframes saved for date 2022-05-27
# Moneyness and standardized moneyness dataframes saved for date 2022-05-28
# Moneyness and standardized moneyness dataframes saved for date 2022-05-29
# Moneyness and standardized moneyness dataframes saved for date 2022-05-30
# Moneyness and standardized moneyness dataframes saved for date 2022-05-31
# Moneyness and standardized moneyness dataframes saved for date 2022-06-01
# Moneyness and standardized moneyness dataframes saved for date 2022-06-02
# Moneyness and standardized moneyness dataframes saved for date 2022-06-03
# Moneyness and standardized moneyness dataframes saved for date 2022-06-04
# Moneyness and standardized moneyness dataframes saved for date 2022-06-05
# Moneyness and standardized moneyness dataframes saved for date 2022-06-06
# Moneyness and standardized moneyness dataframes saved for date 2022-06-07
# Moneyness and standardized moneyness dataframes saved for date 2022-06-08
# Moneyness and standardized moneyness dataframes saved for date 2022-06-09
# Moneyness and standardized moneyness dataframes saved for date 2022-06-10
# Moneyness and standardized moneyness dataframes saved for date 2022-06-11
# Moneyness and standardized moneyness dataframes saved for date 2022-06-12
# Moneyness and standardized moneyness dataframes saved for date 2022-06-13
# Moneyness and standardized moneyness dataframes saved for date 2022-06-14
# Moneyness and standardized moneyness dataframes saved for date 2022-06-15
# Moneyness and standardized moneyness dataframes saved for date 2022-06-16
# Moneyness and standardized moneyness dataframes saved for date 2022-06-17
# Moneyness and standardized moneyness dataframes saved for date 2022-06-18
# Moneyness and standardized moneyness dataframes saved for date 2022-06-19
# Moneyness and standardized moneyness dataframes saved for date 2022-06-20
# Moneyness and standardized moneyness dataframes saved for date 2022-06-21
# Moneyness and standardized moneyness dataframes saved for date 2022-06-22
# Moneyness and standardized moneyness dataframes saved for date 2022-06-23
# Moneyness and standardized moneyness dataframes saved for date 2022-06-24
# Moneyness and standardized moneyness dataframes saved for date 2022-06-25
# Moneyness and standardized moneyness dataframes saved for date 2022-06-26
# Moneyness and standardized moneyness dataframes saved for date 2022-06-27
# Moneyness and standardized moneyness dataframes saved for date 2022-06-28
# Moneyness and standardized moneyness dataframes saved for date 2022-06-29
# Moneyness and standardized moneyness dataframes saved for date 2022-06-30
# Moneyness and standardized moneyness dataframes saved for date 2022-07-01
# Moneyness and standardized moneyness dataframes saved for date 2022-07-02
# Moneyness and standardized moneyness dataframes saved for date 2022-07-03
# Moneyness and standardized moneyness dataframes saved for date 2022-07-04
# Moneyness and standardized moneyness dataframes saved for date 2022-07-05
# Moneyness and standardized moneyness dataframes saved for date 2022-07-06
# Moneyness and standardized moneyness dataframes saved for date 2022-07-07
# Moneyness and standardized moneyness dataframes saved for date 2022-07-08
# Moneyness and standardized moneyness dataframes saved for date 2022-07-09
# Moneyness and standardized moneyness dataframes saved for date 2022-07-10
# Moneyness and standardized moneyness dataframes saved for date 2022-07-11
# Moneyness and standardized moneyness dataframes saved for date 2022-07-12
# Moneyness and standardized moneyness dataframes saved for date 2022-07-13
# Moneyness and standardized moneyness dataframes saved for date 2022-07-14
# Moneyness and standardized moneyness dataframes saved for date 2022-07-15
# Moneyness and standardized moneyness dataframes saved for date 2022-07-16
# Moneyness and standardized moneyness dataframes saved for date 2022-07-17
# Moneyness and standardized moneyness dataframes saved for date 2022-07-18
# Moneyness and standardized moneyness dataframes saved for date 2022-07-19
# Moneyness and standardized moneyness dataframes saved for date 2022-07-20
# Moneyness and standardized moneyness dataframes saved for date 2022-07-21
# Moneyness and standardized moneyness dataframes saved for date 2022-07-22
# Moneyness and standardized moneyness dataframes saved for date 2022-07-23
# Moneyness and standardized moneyness dataframes saved for date 2022-07-24
# Moneyness and standardized moneyness dataframes saved for date 2022-07-25
# Moneyness and standardized moneyness dataframes saved for date 2022-07-26
# Moneyness and standardized moneyness dataframes saved for date 2022-07-27
# Moneyness and standardized moneyness dataframes saved for date 2022-07-28
# Moneyness and standardized moneyness dataframes saved for date 2022-07-29
# Moneyness and standardized moneyness dataframes saved for date 2022-07-30
# Moneyness and standardized moneyness dataframes saved for date 2022-07-31
# Moneyness and standardized moneyness dataframes saved for date 2022-08-01
# Moneyness and standardized moneyness dataframes saved for date 2022-08-02
# Moneyness and standardized moneyness dataframes saved for date 2022-08-03
# Moneyness and standardized moneyness dataframes saved for date 2022-08-04
# Moneyness and standardized moneyness dataframes saved for date 2022-08-05
# Moneyness and standardized moneyness dataframes saved for date 2022-08-06
# Moneyness and standardized moneyness dataframes saved for date 2022-08-07
# Moneyness and standardized moneyness dataframes saved for date 2022-08-08
# Moneyness and standardized moneyness dataframes saved for date 2022-08-09
# Moneyness and standardized moneyness dataframes saved for date 2022-08-10
# Moneyness and standardized moneyness dataframes saved for date 2022-08-11
# Moneyness and standardized moneyness dataframes saved for date 2022-08-12
# Moneyness and standardized moneyness dataframes saved for date 2022-08-13
# Moneyness and standardized moneyness dataframes saved for date 2022-08-14
# Moneyness and standardized moneyness dataframes saved for date 2022-08-15
# Moneyness and standardized moneyness dataframes saved for date 2022-08-16
# Moneyness and standardized moneyness dataframes saved for date 2022-08-17
# Moneyness and standardized moneyness dataframes saved for date 2022-08-18
# Moneyness and standardized moneyness dataframes saved for date 2022-08-19
# Moneyness and standardized moneyness dataframes saved for date 2022-08-20
# Moneyness and standardized moneyness dataframes saved for date 2022-08-21
# Moneyness and standardized moneyness dataframes saved for date 2022-08-22
# Moneyness and standardized moneyness dataframes saved for date 2022-08-23
# Moneyness and standardized moneyness dataframes saved for date 2022-08-24
# Moneyness and standardized moneyness dataframes saved for date 2022-08-25
# Moneyness and standardized moneyness dataframes saved for date 2022-08-26
# Moneyness and standardized moneyness dataframes saved for date 2022-08-27
# Moneyness and standardized moneyness dataframes saved for date 2022-08-28
# Moneyness and standardized moneyness dataframes saved for date 2022-08-29
# Moneyness and standardized moneyness dataframes saved for date 2022-08-30
# Moneyness and standardized moneyness dataframes saved for date 2022-08-31
# Moneyness and standardized moneyness dataframes saved for date 2022-09-01
# Moneyness and standardized moneyness dataframes saved for date 2022-09-02
# Moneyness and standardized moneyness dataframes saved for date 2022-09-03
# Moneyness and standardized moneyness dataframes saved for date 2022-09-04
# Moneyness and standardized moneyness dataframes saved for date 2022-09-05
# Moneyness and standardized moneyness dataframes saved for date 2022-09-06
# Moneyness and standardized moneyness dataframes saved for date 2022-09-07
# Moneyness and standardized moneyness dataframes saved for date 2022-09-08
# Moneyness and standardized moneyness dataframes saved for date 2022-09-09
# Moneyness and standardized moneyness dataframes saved for date 2022-09-10
# Moneyness and standardized moneyness dataframes saved for date 2022-09-11
# Moneyness and standardized moneyness dataframes saved for date 2022-09-12
# Moneyness and standardized moneyness dataframes saved for date 2022-09-13
# Moneyness and standardized moneyness dataframes saved for date 2022-09-14
# Moneyness and standardized moneyness dataframes saved for date 2022-09-15
# Moneyness and standardized moneyness dataframes saved for date 2022-09-16
# Moneyness and standardized moneyness dataframes saved for date 2022-09-17
# Moneyness and standardized moneyness dataframes saved for date 2022-09-18
# Moneyness and standardized moneyness dataframes saved for date 2022-09-19
# Moneyness and standardized moneyness dataframes saved for date 2022-09-20
# Moneyness and standardized moneyness dataframes saved for date 2022-09-21
# Moneyness and standardized moneyness dataframes saved for date 2022-09-22
# Moneyness and standardized moneyness dataframes saved for date 2022-09-23
# Moneyness and standardized moneyness dataframes saved for date 2022-09-24
# Moneyness and standardized moneyness dataframes saved for date 2022-09-25
# Moneyness and standardized moneyness dataframes saved for date 2022-09-26
# Moneyness and standardized moneyness dataframes saved for date 2022-09-27
# Moneyness and standardized moneyness dataframes saved for date 2022-09-28
# Moneyness and standardized moneyness dataframes saved for date 2022-09-29
# Moneyness and standardized moneyness dataframes saved for date 2022-09-30
# Moneyness and standardized moneyness dataframes saved for date 2022-10-01
# Moneyness and standardized moneyness dataframes saved for date 2022-10-02
# Moneyness and standardized moneyness dataframes saved for date 2022-10-03
# Moneyness and standardized moneyness dataframes saved for date 2022-10-04
# Moneyness and standardized moneyness dataframes saved for date 2022-10-05
# Moneyness and standardized moneyness dataframes saved for date 2022-10-06
# Moneyness and standardized moneyness dataframes saved for date 2022-10-07
# Moneyness and standardized moneyness dataframes saved for date 2022-10-08
# Moneyness and standardized moneyness dataframes saved for date 2022-10-09
# Moneyness and standardized moneyness dataframes saved for date 2022-10-10
# Moneyness and standardized moneyness dataframes saved for date 2022-10-11
# Moneyness and standardized moneyness dataframes saved for date 2022-10-12
# Moneyness and standardized moneyness dataframes saved for date 2022-10-13
# Moneyness and standardized moneyness dataframes saved for date 2022-10-14
# Moneyness and standardized moneyness dataframes saved for date 2022-10-15
# Moneyness and standardized moneyness dataframes saved for date 2022-10-16
# Moneyness and standardized moneyness dataframes saved for date 2022-10-17
# Moneyness and standardized moneyness dataframes saved for date 2022-10-18
# Moneyness and standardized moneyness dataframes saved for date 2022-10-19
# Moneyness and standardized moneyness dataframes saved for date 2022-10-20
# Moneyness and standardized moneyness dataframes saved for date 2022-10-21
# Moneyness and standardized moneyness dataframes saved for date 2022-10-22
# Moneyness and standardized moneyness dataframes saved for date 2022-10-23
# Moneyness and standardized moneyness dataframes saved for date 2022-10-24
# Moneyness and standardized moneyness dataframes saved for date 2022-10-25
# Moneyness and standardized moneyness dataframes saved for date 2022-10-26
# Moneyness and standardized moneyness dataframes saved for date 2022-10-27
# Moneyness and standardized moneyness dataframes saved for date 2022-10-28
# Moneyness and standardized moneyness dataframes saved for date 2022-10-29
# Moneyness and standardized moneyness dataframes saved for date 2022-10-30
# Moneyness and standardized moneyness dataframes saved for date 2022-10-31
# Moneyness and standardized moneyness dataframes saved for date 2022-11-01
# Moneyness and standardized moneyness dataframes saved for date 2022-11-02
# Moneyness and standardized moneyness dataframes saved for date 2022-11-03
# Moneyness and standardized moneyness dataframes saved for date 2022-11-04
# Moneyness and standardized moneyness dataframes saved for date 2022-11-05
# Moneyness and standardized moneyness dataframes saved for date 2022-11-06
# Moneyness and standardized moneyness dataframes saved for date 2022-11-07
# Moneyness and standardized moneyness dataframes saved for date 2022-11-08
# Moneyness and standardized moneyness dataframes saved for date 2022-11-09
# Moneyness and standardized moneyness dataframes saved for date 2022-11-10
# Moneyness and standardized moneyness dataframes saved for date 2022-11-11
# Moneyness and standardized moneyness dataframes saved for date 2022-11-12
# Moneyness and standardized moneyness dataframes saved for date 2022-11-13
# Moneyness and standardized moneyness dataframes saved for date 2022-11-14
# Moneyness and standardized moneyness dataframes saved for date 2022-11-15
# Moneyness and standardized moneyness dataframes saved for date 2022-11-16
# Moneyness and standardized moneyness dataframes saved for date 2022-11-17
# Moneyness and standardized moneyness dataframes saved for date 2022-11-18
# Moneyness and standardized moneyness dataframes saved for date 2022-11-19
# Moneyness and standardized moneyness dataframes saved for date 2022-11-20
# Moneyness and standardized moneyness dataframes saved for date 2022-11-21
# Moneyness and standardized moneyness dataframes saved for date 2022-11-22
# Moneyness and standardized moneyness dataframes saved for date 2022-11-23
# Moneyness and standardized moneyness dataframes saved for date 2022-11-24
# Moneyness and standardized moneyness dataframes saved for date 2022-11-25
# Moneyness and standardized moneyness dataframes saved for date 2022-11-26
# Moneyness and standardized moneyness dataframes saved for date 2022-11-27
# Moneyness and standardized moneyness dataframes saved for date 2022-11-28
# Moneyness and standardized moneyness dataframes saved for date 2022-11-29
# Moneyness and standardized moneyness dataframes saved for date 2022-11-30
# Moneyness and standardized moneyness dataframes saved for date 2022-12-01
# Moneyness and standardized moneyness dataframes saved for date 2022-12-02
# Moneyness and standardized moneyness dataframes saved for date 2022-12-03
# Moneyness and standardized moneyness dataframes saved for date 2022-12-04
# Moneyness and standardized moneyness dataframes saved for date 2022-12-05
# Moneyness and standardized moneyness dataframes saved for date 2022-12-06
# Moneyness and standardized moneyness dataframes saved for date 2022-12-07
# Moneyness and standardized moneyness dataframes saved for date 2022-12-08
# Moneyness and standardized moneyness dataframes saved for date 2022-12-09
# Moneyness and standardized moneyness dataframes saved for date 2022-12-10
# Moneyness and standardized moneyness dataframes saved for date 2022-12-11
# Moneyness and standardized moneyness dataframes saved for date 2022-12-12
# Moneyness and standardized moneyness dataframes saved for date 2022-12-13

# %%
# Identify duplicate rows with the same moneyness and tau
duplicates = df[df.duplicated(subset=['date', 'moneyness', 'tau'], keep=False)]

# Save duplicates to a CSV file for review
duplicates_save_path = os.path.join(path, "data", "processed", "20172022_1_3_5_duplicates_moneyness_tau.csv")
duplicates.to_csv(duplicates_save_path, index=False)

print("Duplicate rows with the same moneyness and tau saved to '20172022_1_3_5_duplicates_moneyness_tau.csv'")
# Out:
# Duplicate rows with the same moneyness and tau saved to '20172022_1_3_5_duplicates_moneyness_tau.csv'

# %%
print(duplicates.head())
print("The shape of duplicates is: ",duplicates.shape)
# Out:
# Empty DataFrame
# Columns: [date, tau, moneyness, quantity, option_price, IV, IV_atm, moneyness_atm, standardized_moneyness]
# Index: []
# The shape of duplicates is:  (0, 9)
